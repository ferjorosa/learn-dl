# %% [markdown]
# <a href="https://colab.research.google.com/github/ferjorosa/learn-fastai/blob/main/5%20-%20Image%20Classification/05_pet_breeds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hide (Google Colab)
# !pip install fastai --upgrade -q
import fastai
print(fastai.__version__)

# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 189 kB 5.3 MB/s
#      |████████████████████████████████| 56 kB 4.9 MB/s
# 2.5.3
#      |████████████████████████████████| 720 kB 5.2 MB/s
#      |████████████████████████████████| 46 kB 627 kB/s
#      |████████████████████████████████| 1.2 MB 41.7 MB/s
#      |████████████████████████████████| 51 kB 370 kB/s
# Mounted at /content/gdrive

# %%
#hide
from fastbook import *

# %% [markdown]
# # Image Classification

# %% [markdown]
# ## From Dogs and Cats to Pet Breeds

# %%
from fastai.vision.all import *
path = untar_data(URLs.PETS)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='811712512' class='' max='811706944' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [811712512/811706944 00:22<00:00]
#     </div>

# %%
#hide
Path.BASE_PATH = path

# %%
path.ls()
# Out:
# (#2) [Path('images'),Path('annotations')]

# %%
(path/"images").ls()
# Out:
# (#7393) [Path('images/Bengal_82.jpg'),Path('images/leonberger_29.jpg'),Path('images/Birman_79.jpg'),Path('images/german_shorthaired_37.jpg'),Path('images/Maine_Coon_253.jpg'),Path('images/Abyssinian_178.jpg'),Path('images/shiba_inu_42.jpg'),Path('images/Persian_102.jpg'),Path('images/wheaten_terrier_127.jpg'),Path('images/pomeranian_61.jpg')...]

# %%
fname = (path/"images").ls()[0]

# %%
Image.open((path/"images/chihuahua_45.jpg"))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7FD6FE036610>

# %%
re.findall(r'(.+)_\d+.jpg$', fname.name)
# Out:
# ['Bengal']

# %%
pets = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=RandomSplitter(seed=42),
                 get_y=using_attr(RegexLabeller(r'(.+)_\d+.jpg$'), 'name'),
                 item_tfms=Resize(460),
                 batch_tfms=aug_transforms(size=224, min_scale=0.75))
dls = pets.dataloaders(path/"images")
dls.show_batch(nrows=1, ncols=3)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %%
pets

# %% [markdown]
# ## Presizing

# %%
# dblock1 = DataBlock(blocks=(ImageBlock(), CategoryBlock()),
#                    get_y=parent_label,
#                    item_tfms=Resize(460))
# dls1 = dblock1.dataloaders([(Path.cwd()/'images'/'grizzly.jpg')]*100, bs=8)
# dls1.train.get_idxs = lambda: Inf.ones
# x,y = dls1.valid.one_batch()
# _,axs = subplots(1, 2)

# x1 = TensorImage(x.clone())
# x1 = x1.affine_coord(sz=224)
# x1 = x1.rotate(draw=30, p=1.)
# x1 = x1.zoom(draw=1.2, p=1.)
# x1 = x1.warp(draw_x=-0.2, draw_y=0.2, p=1.)

# tfms = setup_aug_tfms([Rotate(draw=30, p=1, size=224), Zoom(draw=1.2, p=1., size=224),
#                        Warp(draw_x=-0.2, draw_y=0.2, p=1., size=224)])
# x = Pipeline(tfms)(x)
# #x.affine_coord(coord_tfm=coord_tfm, sz=size, mode=mode, pad_mode=pad_mode)
# TensorImage(x[0]).show(ctx=axs[0])
# TensorImage(x1[0]).show(ctx=axs[1]);

# %% [markdown]
# ### Checking and Debugging a DataBlock

# %%
dls.show_batch(nrows=1, ncols=3)

# %%
pets1 = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=RandomSplitter(seed=42),
                 get_y=using_attr(RegexLabeller(r'(.+)_\d+.jpg$'), 'name'),
                 item_tfms=Resize(335))
dls1 = pets1.dataloaders(path/"images")
# pets1.summary(path/"images")
dls1.show_batch(nrows=1, ncols=3)

# %%
learn = cnn_learner(dls1, resnet34, metrics=error_rate)
learn.fine_tune(2)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.545261</td>
#       <td>0.270072</td>
#       <td>0.090663</td>
#       <td>03:21</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.431914</td>
#       <td>0.255371</td>
#       <td>0.079838</td>
#       <td>04:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.205942</td>
#       <td>0.170536</td>
#       <td>0.052097</td>
#       <td>04:44</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Cross-Entropy Loss

# %% [markdown]
# ### Viewing Activations and Labels

# %%
x,y = dls.one_batch()

# %%
y
# Out:
# TensorCategory([30,  2, 19, 13, 21,  9, 13, 35,  7, 30, 13, 15, 34, 10,  4, 12, 32, 23, 23,  8,  3, 11, 34,  3, 35, 22, 14,  5, 17, 35, 29,  2, 23, 31, 33, 36,  3,  8,  1, 31, 36, 23, 25,  9,  8, 33, 28, 21,
#         31, 24,  5, 16,  3, 29, 22, 17,  0,  2, 11,  9, 33, 13, 23, 15], device='cuda:0')

# %%
preds,_ = learn.get_preds(dl=[(x,y)])
preds[0]
# Out:
# TensorBase([5.4111e-06, 3.5036e-06, 4.5154e-05, 2.8925e-07, 1.1635e-07, 1.5532e-06, 6.6188e-06, 1.9323e-05, 1.3450e-05, 2.1489e-07, 1.9031e-07, 1.2402e-06, 9.1261e-03, 9.5916e-06, 3.9892e-04, 3.8177e-05,
#         2.0956e-04, 3.8825e-07, 7.2959e-06, 2.3790e-05, 1.9539e-06, 1.4890e-04, 8.0279e-05, 1.3849e-04, 2.9051e-06, 7.3326e-04, 9.0845e-08, 1.5349e-05, 4.7510e-07, 9.9641e-07, 9.8896e-01, 4.7110e-06,
#         1.7693e-07, 5.9603e-07, 4.0687e-07, 4.7305e-07, 1.2513e-06])

# %%
len(preds[0]),preds[0].sum()
# Out:
# (37, TensorBase(1.))

# %% [markdown]
# ### Softmax

# %%
plot_function(torch.sigmoid, min=-4,max=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastbook/__init__.py:74: UserWarning: Not providing a value for linspace's steps is deprecated and will throw a runtime error in a future release. This warning will appear only once per process. (Triggered internally at  ../aten/src/ATen/native/RangeFactories.cpp:23.)
#   x = torch.linspace(min,max)

# %%
#hide
torch.random.manual_seed(42);

# %%
acts = torch.randn((6,2))*2
acts
# Out:
# tensor([[ 0.6734,  0.2576],
#         [ 0.4689,  0.4607],
#         [-2.2457, -0.3727],
#         [ 4.4164, -1.2760],
#         [ 0.9233,  0.5347],
#         [ 1.0698,  1.6187]])

# %%
acts.sigmoid()
# Out:
# tensor([[0.6623, 0.5641],
#         [0.6151, 0.6132],
#         [0.0957, 0.4079],
#         [0.9881, 0.2182],
#         [0.7157, 0.6306],
#         [0.7446, 0.8346]])

# %%
(acts[:,0]-acts[:,1]).sigmoid()
# Out:
# tensor([0.6025, 0.5021, 0.1332, 0.9966, 0.5959, 0.3661])

# %%
sm_acts = torch.softmax(acts, dim=1)
sm_acts
# Out:
# tensor([[0.6025, 0.3975],
#         [0.5021, 0.4979],
#         [0.1332, 0.8668],
#         [0.9966, 0.0034],
#         [0.5959, 0.4041],
#         [0.3661, 0.6339]])

# %% [markdown]
# ### Log Likelihood

# %%
targ = tensor([0,1,0,1,1,0])

# %%
sm_acts
# Out:
# tensor([[0.6025, 0.3975],
#         [0.5021, 0.4979],
#         [0.1332, 0.8668],
#         [0.9966, 0.0034],
#         [0.5959, 0.4041],
#         [0.3661, 0.6339]])

# %%
idx = range(6)
sm_acts[idx, targ]
# Out:
# tensor([0.6025, 0.4979, 0.1332, 0.0034, 0.4041, 0.3661])

# %%
from IPython.display import HTML
df = pd.DataFrame(sm_acts, columns=["3","7"])
df['targ'] = targ
df['idx'] = idx
df['loss'] = sm_acts[range(6), targ]
t = df.style.hide_index()
#To have html code compatible with our script
html = t._repr_html_().split('</style>')[1]
html = re.sub(r'<table id="([^"]+)"\s*>', r'<table >', html)
display(HTML(html))
# Out:
# <table >
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >3</th>
#       <th class="col_heading level0 col1" >7</th>
#       <th class="col_heading level0 col2" >targ</th>
#       <th class="col_heading level0 col3" >idx</th>
#       <th class="col_heading level0 col4" >loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3d8ae_row0_col0" class="data row0 col0" >0.602469</td>
#       <td id="T_3d8ae_row0_col1" class="data row0 col1" >0.397531</td>
#       <td id="T_3d8ae_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_3d8ae_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3d8ae_row0_col4" class="data row0 col4" >0.602469</td>
#     </tr>
#     <tr>
#       <td id="T_3d8ae_row1_col0" class="data row1 col0" >0.502065</td>
#       <td id="T_3d8ae_row1_col1" class="data row1 col1" >0.497935</td>
#       <td id="T_3d8ae_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_3d8ae_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_3d8ae_row1_col4" class="data row1 col4" >0.497935</td>
#     </tr>
#     <tr>
#       <td id="T_3d8ae_row2_col0" class="data row2 col0" >0.133188</td>
#       <td id="T_3d8ae_row2_col1" class="data row2 col1" >0.866811</td>
#       <td id="T_3d8ae_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_3d8ae_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_3d8ae_row2_col4" class="data row2 col4" >0.133188</td>
#     </tr>
#     <tr>
#       <td id="T_3d8ae_row3_col0" class="data row3 col0" >0.996640</td>
#       <td id="T_3d8ae_row3_col1" class="data row3 col1" >0.003360</td>
#       <td id="T_3d8ae_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_3d8ae_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_3d8ae_row3_col4" class="data row3 col4" >0.003360</td>
#     </tr>
#     <tr>
#       <td id="T_3d8ae_row4_col0" class="data row4 col0" >0.595949</td>
#       <td id="T_3d8ae_row4_col1" class="data row4 col1" >0.404051</td>
#       <td id="T_3d8ae_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_3d8ae_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_3d8ae_row4_col4" class="data row4 col4" >0.404051</td>
#     </tr>
#     <tr>
#       <td id="T_3d8ae_row5_col0" class="data row5 col0" >0.366118</td>
#       <td id="T_3d8ae_row5_col1" class="data row5 col1" >0.633882</td>
#       <td id="T_3d8ae_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_3d8ae_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_3d8ae_row5_col4" class="data row5 col4" >0.366118</td>
#     </tr>
#   </tbody>
# </table>

# %%
-sm_acts[idx, targ]
# Out:
# tensor([-0.6025, -0.4979, -0.1332, -0.0034, -0.4041, -0.3661])

# %%
F.nll_loss(sm_acts, targ, reduction='none')
# Out:
# tensor([-0.6025, -0.4979, -0.1332, -0.0034, -0.4041, -0.3661])

# %% [markdown]
# ### Taking the Log

# %%
plot_function(torch.log, min=0,max=4)

# %%
loss_func = nn.CrossEntropyLoss()

# %%
loss_func(acts, targ)
# Out:
# tensor(1.8045)

# %%
F.cross_entropy(acts, targ)
# Out:
# tensor(1.8045)

# %%
nn.CrossEntropyLoss(reduction='none')(acts, targ)
# Out:
# tensor([0.5067, 0.6973, 2.0160, 5.6958, 0.9062, 1.0048])

# %% [markdown]
# ## Model Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=5)
# Out:
# [('american_pit_bull_terrier', 'staffordshire_bull_terrier', 7),
#  ('Egyptian_Mau', 'Bengal', 5),
#  ('Ragdoll', 'Birman', 5)]

# %% [markdown]
# ## Improving Our Model

# %% [markdown]
# ### The Learning Rate Finder

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1, base_lr=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.636191</td>
#       <td>3.820801</td>
#       <td>0.403248</td>
#       <td>02:09</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.901145</td>
#       <td>2.353578</td>
#       <td>0.677943</td>
#       <td>02:41</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
lr_min = learn.lr_find()

# %%
print(lr_min)
# Out:
# SuggestedLRs(valley=0.0010000000474974513)

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(2, base_lr=3e-3) #old lr_find (2 returns, min and steepest point)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.318575</td>
#       <td>0.319384</td>
#       <td>0.098782</td>
#       <td>02:05</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.568978</td>
#       <td>0.458700</td>
#       <td>0.136671</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.342341</td>
#       <td>0.229810</td>
#       <td>0.075101</td>
#       <td>02:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(2, base_lr=1e-3) #new lr_find (only 1 return, min)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.035480</td>
#       <td>0.378672</td>
#       <td>0.125169</td>
#       <td>02:05</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.566366</td>
#       <td>0.279879</td>
#       <td>0.092693</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.399977</td>
#       <td>0.230668</td>
#       <td>0.077808</td>
#       <td>02:39</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Unfreezing and Transfer Learning

# %%
learn.fine_tune??

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fit_one_cycle(3, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.175874</td>
#       <td>0.354742</td>
#       <td>0.107578</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531915</td>
#       <td>0.234069</td>
#       <td>0.085250</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.329624</td>
#       <td>0.209900</td>
#       <td>0.067659</td>
#       <td>02:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=2.511886486900039e-05)

# %%
learn.fit_one_cycle(6, lr_max=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.255844</td>
#       <td>0.208161</td>
#       <td>0.067659</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.238473</td>
#       <td>0.205247</td>
#       <td>0.066982</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.211213</td>
#       <td>0.198744</td>
#       <td>0.060217</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.217060</td>
#       <td>0.186782</td>
#       <td>0.063599</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.194994</td>
#       <td>0.186899</td>
#       <td>0.058863</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.183452</td>
#       <td>0.190181</td>
#       <td>0.062923</td>
#       <td>02:40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Discriminative Learning Rates

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fit_one_cycle(3, 3e-3)
learn.unfreeze()
learn.fit_one_cycle(12, lr_max=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.127224</td>
#       <td>0.315381</td>
#       <td>0.108254</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.507386</td>
#       <td>0.257056</td>
#       <td>0.085927</td>
#       <td>02:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.324157</td>
#       <td>0.219449</td>
#       <td>0.074425</td>
#       <td>02:04</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.270432</td>
#       <td>0.211059</td>
#       <td>0.070365</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.236891</td>
#       <td>0.210238</td>
#       <td>0.069012</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.221744</td>
#       <td>0.204447</td>
#       <td>0.066306</td>
#       <td>02:37</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.227562</td>
#       <td>0.198333</td>
#       <td>0.065629</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.193237</td>
#       <td>0.193777</td>
#       <td>0.062923</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.179495</td>
#       <td>0.188535</td>
#       <td>0.062923</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.167190</td>
#       <td>0.184114</td>
#       <td>0.061570</td>
#       <td>02:38</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.151030</td>
#       <td>0.180378</td>
#       <td>0.060217</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.136731</td>
#       <td>0.175572</td>
#       <td>0.055480</td>
#       <td>02:42</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.132937</td>
#       <td>0.179306</td>
#       <td>0.058863</td>
#       <td>02:42</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.118354</td>
#       <td>0.173683</td>
#       <td>0.056834</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.119145</td>
#       <td>0.176944</td>
#       <td>0.059540</td>
#       <td>02:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %% [markdown]
# ### Selecting the Number of Epochs

# %% [markdown]
# ### Deeper Architectures

# %%
from fastai.callback.fp16 import *
learn = cnn_learner(dls, resnet50, metrics=error_rate).to_fp16()
learn.fine_tune(6, freeze_epochs=3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.257122</td>
#       <td>0.293162</td>
#       <td>0.096752</td>
#       <td>02:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.581938</td>
#       <td>0.283294</td>
#       <td>0.093369</td>
#       <td>02:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.411452</td>
#       <td>0.202656</td>
#       <td>0.070365</td>
#       <td>02:25</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.270107</td>
#       <td>0.244698</td>
#       <td>0.078484</td>
#       <td>03:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.336491</td>
#       <td>0.263159</td>
#       <td>0.091340</td>
#       <td>03:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.253792</td>
#       <td>0.228887</td>
#       <td>0.068336</td>
#       <td>03:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.156883</td>
#       <td>0.202174</td>
#       <td>0.062923</td>
#       <td>03:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.082652</td>
#       <td>0.174300</td>
#       <td>0.058187</td>
#       <td>03:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.057453</td>
#       <td>0.176609</td>
#       <td>0.061570</td>
#       <td>03:11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Why do we first resize to a large size on the CPU, and then to a smaller size on the GPU?
# 1. If you are not familiar with regular expressions, find a regular expression tutorial, and some problem sets, and complete them. Have a look on the book's website for suggestions.
# 1. What are the two ways in which data is most commonly provided, for most deep learning datasets?
# 1. Look up the documentation for `L` and try using a few of the new methods that it adds.
# 1. Look up the documentation for the Python `pathlib` module and try using a few methods of the `Path` class.
# 1. Give two examples of ways that image transformations can degrade the quality of the data.
# 1. What method does fastai provide to view the data in a `DataLoaders`?
# 1. What method does fastai provide to help you debug a `DataBlock`?
# 1. Should you hold off on training a model until you have thoroughly cleaned your data?
# 1. What are the two pieces that are combined into cross-entropy loss in PyTorch?
# 1. What are the two properties of activations that softmax ensures? Why is this important?
# 1. When might you want your activations to not have these two properties?
# 1. Calculate the `exp` and `softmax` columns of <<bear_softmax>> yourself (i.e., in a spreadsheet, with a calculator, or in a notebook).
# 1. Why can't we use `torch.where` to create a loss function for datasets where our label can have more than two categories?
# 1. What is the value of log(-2)? Why?
# 1. What are two good rules of thumb for picking a learning rate from the learning rate finder?
# 1. What two steps does the `fine_tune` method do?
# 1. In Jupyter Notebook, how do you get the source code for a method or function?
# 1. What are discriminative learning rates?
# 1. How is a Python `slice` object interpreted when passed as a learning rate to fastai?
# 1. Why is early stopping a poor choice when using 1cycle training?
# 1. What is the difference between `resnet50` and `resnet101`?
# 1. What does `to_fp16` do?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Find the paper by Leslie Smith that introduced the learning rate finder, and read it.
# 1. See if you can improve the accuracy of the classifier in this chapter. What's the best accuracy you can achieve? Look on the forums and the book's website to see what other students have achieved with this dataset, and how they did it.
