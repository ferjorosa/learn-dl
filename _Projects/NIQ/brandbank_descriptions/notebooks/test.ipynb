# %%
import pandas as pd

df_chars = pd.read_parquet("/home/azureuser/cloudfiles/code/Users/Fernando.Rodriguez/ainn-eliza-rnd-data/multimodal_dataloader_v1/data/brandbank_5000_examples_10_groups/splits/brandbank_5000_examples_10_groups_train/chars.parquet")

# %%
df_chars
# Out:
#       PRODUCT_ID  EXTERNAL_CODE GROUP_CODE       CREATION_DATE  \
# 0        9898540  7790168000570      GB004 2022-01-10 16:44:47
# 1       23242421  5054268676113      GB146 2015-09-03 15:33:28
# 2       22374851  5060045388117      GB146 2015-08-15 18:26:30
# 3       76697077  8006540444511      GB102 2022-12-27 18:11:45
# 4       44761354  5053990107476      GB146 2021-06-10 14:07:20
# ...          ...            ...        ...                 ...
# 4953    15390929  0079400197023      GB004 2021-05-04 16:35:06
# 4954    41009289  5031396032202      GB105 2022-01-26 12:54:53
# 4956    23816658  5054402526670      GB126 2022-10-05 15:12:44
# 4957    24069034  5054070671047      GB032 2015-06-08 10:48:20
# 4958    24807007  5054781053996      GB032 2015-12-01 07:42:37
#
#                                PRODUCT_GROUP  \
# 0                  WINE - LIGHT/TABLE STYLES
# 1                  WINE - LIGHT/TABLE STYLES
# 2                           DESSERTS - FRESH
# ...
